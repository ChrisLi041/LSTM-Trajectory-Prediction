# %%
# from google.colab import drive
import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
import random
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from tqdm import tqdm as tqdm
from keras.layers import *
from keras.models import *
from sklearn.preprocessing import MinMaxScaler
import pickle
from google.colab import drive
drive.mount('/content/drive')
Path = 'drive/MyDrive/Traffic_data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#  import torch
# seed = 1024
# nrows = 150159

# how many vehicles?
nrows = 150000
feature_names = ['ego_x',"ego_v", 'f_dx', 'f_dy', 'f_dv', 'b_dx', 'b_dy','b_dv', 'l_dx', 'l_dy', 'l_dv', 'r_dx', 'r_dy', 'r_dv']
# Label1: Ego vehicle lateral displacement
label_names_1 = ['ego_x']

# Label2: Ego vehicle longitudinal velocity
label_names_2 = ['ego_v']
# label_name = 'ego_v'
time_columns = "index"

full_path = Path+'/Final_result.xlsx' 

###############################
# nrows = 150158+1
################################

train_rows=int(nrows*0.7) 
epoch_no = 200
batch_size_RNN = 64
n_in = 10
n_out = 8

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm as tqdm
from sklearn.preprocessing import MinMaxScaler
import h5py
df = pd.read_excel(full_path,parse_dates=[time_columns],nrows=nrows)
df = df.sort_values(time_columns)
df.index = np.arange(df.shape[0])

# %%
df2=df.iloc[0:nrows,:]

# %%
df2
# Out:
#          index      ego_x      ego_v  ...       r_dx        r_dy      r_dv
# 0            0  51.816071  34.006429  ...  30.000000  300.000000  0.000000
# 1            1  52.726857  35.324286  ...  30.000000  300.000000  0.000000
# 2            2  53.001810  37.491429  ...  30.000000  300.000000  0.000000
# 3            3  56.291381  39.865238  ...  30.000000  300.000000  0.000000
# 4            4  29.079835  33.970674  ...   9.564515    9.564515  0.190448
# ...        ...        ...        ...  ...        ...         ...       ...
# 149995  149995  30.175887  29.578032  ...  10.865903   10.865903  0.087921
# 149996  149996  30.138191  30.844701  ...  10.678640   10.678640 -1.189021
# 149997  149997  30.005062  32.219083  ...  13.651970   13.651970 -2.218399
# 149998  149998  29.897249  33.539044  ...  14.242867   14.242867 -4.316660
# 149999  149999  30.018225  34.572602  ...  14.459197   14.459197 -6.381594
#
# [150000 rows x 15 columns]

# %% [markdown]
# ## **Trial**

# %%
from time import thread_time
from numpy.core.numeric import NaN
e = df2.get(label_names_1)
e = e.values.tolist()
# exam = []
# for m in e:
#   exam.append(m[0])
# # print(exam)
# # print(((exam)))
# # plt.figure(figsize=(80, 12))  
# # plt.plot(exam)
# # plt.legend(loc='best', fontsize='12')
# # plt.xticks(fontsize=12)
# # plt.yticks(fontsize=12)
# # plt.title('Lateral Position Prediction w/ Train dataset (5s Forecast)', fontsize='16')
# # plt.xlabel('Time (s)', fontsize='14')
# # plt.ylabel('Relative Lateral Position (m)', fontsize='14')
# # plt.show
# # print(len(exam))

# copy = exam.copy()
# bad_index = []
# threshold = 3
# for i in range(len(exam)-1):
#   now = exam[i]
#   nxt = exam[i+1]
#   if abs(nxt - now) >= threshold:
#     for j in range(i+1, len(exam)):
#         copy[j] -= nxt-now
# # idx = 0
# # while idx != len(exam)-n_out-n_out:
# #   # print(idx)
# #   # print(abs(idx-(len(exam)-n_out-n_out)))
# #   # sum = 0
# #   check = False
# #   for j in exam[idx:idx+n_out-1]:
# #     if abs(exam[idx] - exam[idx+1]) >= threshold:
# #       check = True
# #       idx += n_out
# #       break
# #   if check == False:
# #     dis = np.average(exam[idx:idx+n_out-1])
# #     print(dis)
# #     for k in range(idx, idx+n_out):
# #       copy[k] -= dis
# #     idx += 1



# clean = [x for x in copy if x != -1000]
# cln = []
# for i in clean:
#   cln.append(i[0])
# print(cln)
# clean = [x%10 for x in copy]
plt.figure(figsize=(30, 12))  
plt.plot(e[:1000])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## **LSTM**

# %%
# #Normalization
# scaler_y_1 = MinMaxScaler(feature_range=(-1, 1))
# scaler_y_1.fit(df2[label_names_1].values.astype(float))

# scaler_y_2 = MinMaxScaler(feature_range=(-1, 1))
# scaler_y_2.fit(df2[label_names_2].values.astype(float))

# scaler_x = MinMaxScaler(feature_range=(-1, 1))
# scaler_x.fit(df2[feature_names].values.astype(float))

# %%
## Create dataset
scaler_x_ls = []
scaler_y_1_ls = []
scaler_y_2_ls = []
def create_dataset(df,feature_names,label_names_1,label_names_2,n_in,n_out):
  X, Y1, Y2 = [], [], []
  for i in tqdm(range(df.shape[0]-n_in-n_out+1)):
    check = df[label_names_1].values[i:i+n_in+n_out].astype(float)
    #####################################################################
    jump = False
    for j in range(n_in+n_out-1):
      if abs(check[j] - check[j+1]) > 3.6:
        jump = True
        break
    if jump == True:
      # print("Bad batch, discard the following: ")
      # print(check)
      # i == i + n_out
      # print("haha it is working: and i jumped from " + str(i-n_out)+" to "+str(i)+".")
      continue
    #####################################################################
    x = df[feature_names].values[i:i+n_in].astype(float)
    label1 = df[label_names_1].values[i+n_in:i+n_in+n_out].astype(float)
    label2 = df[label_names_2].values[i+n_in:i+n_in+n_out].astype(float)
    #Normalization
    scaler_x = MinMaxScaler(feature_range=(-1, 1))
    scaler_x.fit(x)
    scaler_x_ls.append(scaler_x)

    scaler_y_1 = MinMaxScaler(feature_range=(-1, 1))
    scaler_y_1.fit(label1)
    scaler_y_1_ls.append(scaler_y_1)

    scaler_y_2 = MinMaxScaler(feature_range=(-1, 1))
    scaler_y_2.fit(label2)
    scaler_y_2_ls.append(scaler_y_2)
    #####################################################################
    x = scaler_x.transform(x)
    label1 = scaler_y_1.transform(label1)
    label2 = scaler_y_2.transform(label2)
    #####################################################################
    X.append(x)
    Y1.append(label1)
    Y2.append(label2)
  return np.array(X),np.array(Y1),np.array(Y2)

# %%
X_1,Y1,Y2 = create_dataset(df2,feature_names,label_names_1,label_names_2,n_in,n_out)
# Out:
# 100%|██████████| 149983/149983 [15:46<00:00, 158.51it/s]

# %%
x1_train, x1_test = X_1[:int(len(X_1)*0.8)], X_1[int(len(X_1)*0.8):]
y1_train, y1_test = Y1[:int(len(Y1)*0.8)], Y1[int(len(Y1)*0.8):]
y2_train, y2_test = Y2[:int(len(Y2)*0.8)], Y2[int(len(Y2)*0.8):]
print(x1_train.shape,x1_test.shape,y1_train.shape,y1_test.shape,y2_train.shape,y2_test.shape)
# Out:
# (94295, 10, 14) (23574, 10, 14) (94295, 8, 1) (23574, 8, 1) (94295, 8, 1) (23574, 8, 1)

# %%
# out=5,y1 ae-lstm
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import RepeatVector,TimeDistributed
y1_train=y1_train.reshape((y1_train.shape[0],y1_train.shape[1]))
# Initialising the RNN
regressor_x = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
layer_1_units=100
regressor_x.add(Bidirectional(LSTM(units = layer_1_units, input_shape = (x1_train.shape[1], x1_train.shape[2]))))
regressor_x.add(RepeatVector(n_out))
regressor_x.add(Bidirectional(LSTM(layer_1_units, activation='relu', return_sequences=True)))
regressor_x.add(TimeDistributed(Dense(1)))

# regressor.add(Dense(units =(y_train.shape[1], y_train.shape[2])))

# Compiling the RNN
regressor_x.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
# epoch_no=20
# batch_size_RNN=64
model_x = regressor_x.fit(x1_train, y1_train, epochs = epoch_no, batch_size = batch_size_RNN)
# Out:
# Epoch 1/200
# 1474/1474 [==============================] - 75s 47ms/step - loss: 0.4230
# Epoch 2/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.3878
# Epoch 3/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.3750
# Epoch 4/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.3626
# Epoch 5/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.3482
# Epoch 6/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.3307
# Epoch 7/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.3092
# Epoch 8/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.2863
# Epoch 9/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.2635
# Epoch 10/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.2415
# Epoch 11/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.2216
# Epoch 12/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.2040
# Epoch 13/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1879
# Epoch 14/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1749
# Epoch 15/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1622
# Epoch 16/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1511
# Epoch 17/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1420
# Epoch 18/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1341
# Epoch 19/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1263
# Epoch 20/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1189
# Epoch 21/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1141
# Epoch 22/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.1086
# Epoch 23/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1030
# Epoch 24/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0995
# Epoch 25/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0954
# Epoch 26/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0918
# Epoch 27/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0884
# Epoch 28/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0857
# Epoch 29/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0821
# Epoch 30/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0793
# Epoch 31/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0777
# Epoch 32/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0755
# Epoch 33/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0729
# Epoch 34/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0712
# Epoch 35/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0696
# Epoch 36/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0681
# Epoch 37/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0658
# Epoch 38/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0645
# Epoch 39/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0635
# Epoch 40/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0619
# Epoch 41/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0604
# Epoch 42/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0596
# Epoch 43/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0588
# Epoch 44/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0568
# Epoch 45/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0562
# Epoch 46/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0559
# Epoch 47/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0544
# Epoch 48/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0537
# Epoch 49/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0522
# Epoch 50/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0521
# Epoch 51/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0516
# Epoch 52/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0501
# Epoch 53/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0490
# Epoch 54/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0493
# Epoch 55/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0486
# Epoch 56/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0476
# Epoch 57/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0467
# Epoch 58/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0470
# Epoch 59/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0452
# Epoch 60/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0457
# Epoch 61/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0437
# Epoch 62/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0440
# Epoch 63/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0435
# Epoch 64/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0443
# Epoch 65/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0421
# Epoch 66/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0425
# Epoch 67/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0421
# Epoch 68/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0410
# Epoch 69/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0403
# Epoch 70/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0416
# Epoch 71/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0395
# Epoch 72/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0394
# Epoch 73/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0398
# Epoch 74/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0392
# Epoch 75/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0385
# Epoch 76/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0389
# Epoch 77/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0379
# Epoch 78/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0379
# Epoch 79/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0378
# Epoch 80/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0369
# Epoch 81/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0370
# Epoch 82/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0369
# Epoch 83/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0362
# Epoch 84/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0355
# Epoch 85/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0365
# Epoch 86/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0355
# Epoch 87/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0345
# Epoch 88/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0352
# Epoch 89/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0355
# Epoch 90/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0333
# Epoch 91/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0351
# Epoch 92/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0338
# Epoch 93/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0343
# Epoch 94/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0332
# Epoch 95/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0336
# Epoch 96/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0323
# Epoch 97/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0341
# Epoch 98/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0330
# Epoch 99/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0324
# Epoch 100/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0323
# Epoch 101/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0313
# Epoch 102/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0329
# Epoch 103/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0318
# Epoch 104/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0318
# Epoch 105/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0308
# Epoch 106/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0311
# Epoch 107/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0317
# Epoch 108/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0306
# Epoch 109/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0316
# Epoch 110/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0300
# Epoch 111/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0310
# Epoch 112/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0294
# Epoch 113/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0299
# Epoch 114/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0303
# Epoch 115/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0294
# Epoch 116/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0311
# Epoch 117/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0284
# Epoch 118/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0295
# Epoch 119/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0291
# Epoch 120/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0297
# Epoch 121/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0287
# Epoch 122/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0301
# Epoch 123/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0283
# Epoch 124/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0289
# Epoch 125/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0281
# Epoch 126/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0285
# Epoch 127/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0287
# Epoch 128/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0286
# Epoch 129/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0274
# Epoch 130/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0278
# Epoch 131/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0277
# Epoch 132/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0292
# Epoch 133/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0260
# Epoch 134/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0285
# Epoch 135/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0269
# Epoch 136/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0271
# Epoch 137/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0278
# Epoch 138/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0274
# Epoch 139/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0265
# Epoch 140/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0271
# Epoch 141/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0260
# Epoch 142/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0281
# Epoch 143/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0255
# Epoch 144/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0272
# Epoch 145/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0275
# Epoch 146/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0251
# Epoch 147/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0262
# Epoch 148/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0263
# Epoch 149/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0262
# Epoch 150/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0251
# Epoch 151/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0268
# Epoch 152/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0255
# Epoch 153/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0246
# Epoch 154/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0253
# Epoch 155/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0255
# Epoch 156/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0243
# Epoch 157/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0259
# Epoch 158/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0251
# Epoch 159/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0243
# Epoch 160/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0259
# Epoch 161/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0240
# Epoch 162/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0259
# Epoch 163/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0258
# Epoch 164/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0235
# Epoch 165/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0232
# Epoch 166/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0271
# Epoch 167/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0240
# Epoch 168/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0234
# Epoch 169/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0242
# Epoch 170/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0252
# Epoch 171/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0229
# Epoch 172/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0252
# Epoch 173/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0234
# Epoch 174/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0243
# Epoch 175/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0249
# Epoch 176/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0234
# Epoch 177/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0232
# Epoch 178/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0230
# Epoch 179/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0246
# Epoch 180/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0230
# Epoch 181/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0236
# Epoch 182/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0235
# Epoch 183/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0235
# Epoch 184/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0244
# Epoch 185/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0234
# Epoch 186/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0207
# Epoch 187/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0236
# Epoch 188/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0237
# Epoch 189/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0222
# Epoch 190/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0237
# Epoch 191/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0230
# Epoch 192/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0217
# Epoch 193/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0234
# Epoch 194/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0221
# Epoch 195/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0226
# Epoch 196/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0229
# Epoch 197/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0222
# Epoch 198/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0236
# Epoch 199/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0220
# Epoch 200/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0210

# %%
# out=10,y2 ae-lstm
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import RepeatVector,TimeDistributed
y2_train=y2_train.reshape((y2_train.shape[0],y2_train.shape[1]))
# Initialising the RNN
regressor_v = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
layer_1_units=100
regressor_v.add(Bidirectional(LSTM(units = layer_1_units, input_shape = (x1_train.shape[1], x1_train.shape[2]))))
regressor_v.add(RepeatVector(n_out))
regressor_v.add(Bidirectional(LSTM(layer_1_units, activation='relu', return_sequences=True)))
regressor_v.add(TimeDistributed(Dense(1)))

# regressor.add(Dense(units =(y_train.shape[1], y_train.shape[2])))

# Compiling the RNN
regressor_v.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
# epoch_no=20
# batch_size_RNN=64
model_v = regressor_v.fit(x1_train, y2_train, epochs = epoch_no, batch_size = batch_size_RNN)
# Out:
# Epoch 1/200
# 1474/1474 [==============================] - 76s 47ms/step - loss: 0.3364
# Epoch 2/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.2966
# Epoch 3/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.2820
# Epoch 4/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.2707
# Epoch 5/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.2596
# Epoch 6/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.2465
# Epoch 7/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.2320
# Epoch 8/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.2151
# Epoch 9/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.1985
# Epoch 10/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.1830
# Epoch 11/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.1678
# Epoch 12/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1548
# Epoch 13/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.1424
# Epoch 14/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1319
# Epoch 15/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1229
# Epoch 16/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1144
# Epoch 17/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.1065
# Epoch 18/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.1002
# Epoch 19/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0945
# Epoch 20/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0891
# Epoch 21/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0847
# Epoch 22/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0809
# Epoch 23/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0772
# Epoch 24/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0740
# Epoch 25/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0700
# Epoch 26/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0676
# Epoch 27/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0657
# Epoch 28/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0623
# Epoch 29/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0606
# Epoch 30/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0578
# Epoch 31/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0568
# Epoch 32/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0551
# Epoch 33/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0526
# Epoch 34/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0514
# Epoch 35/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0507
# Epoch 36/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0489
# Epoch 37/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0474
# Epoch 38/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0470
# Epoch 39/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0452
# Epoch 40/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0441
# Epoch 41/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0435
# Epoch 42/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0421
# Epoch 43/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0409
# Epoch 44/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0409
# Epoch 45/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0398
# Epoch 46/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0382
# Epoch 47/200
# 1474/1474 [==============================] - 73s 50ms/step - loss: 0.0385
# Epoch 48/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0371
# Epoch 49/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0374
# Epoch 50/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0361
# Epoch 51/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0348
# Epoch 52/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0361
# Epoch 53/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0331
# Epoch 54/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0342
# Epoch 55/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0329
# Epoch 56/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0331
# Epoch 57/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0319
# Epoch 58/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0315
# Epoch 59/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0326
# Epoch 60/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0297
# Epoch 61/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0307
# Epoch 62/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0303
# Epoch 63/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0288
# Epoch 64/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0295
# Epoch 65/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0289
# Epoch 66/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0289
# Epoch 67/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0278
# Epoch 68/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0278
# Epoch 69/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0277
# Epoch 70/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0280
# Epoch 71/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0261
# Epoch 72/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0264
# Epoch 73/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0267
# Epoch 74/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0255
# Epoch 75/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0273
# Epoch 76/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0257
# Epoch 77/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0242
# Epoch 78/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0248
# Epoch 79/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0253
# Epoch 80/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0240
# Epoch 81/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0258
# Epoch 82/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0230
# Epoch 83/200
# 1474/1474 [==============================] - 69s 47ms/step - loss: 0.0242
# Epoch 84/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0226
# Epoch 85/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0250
# Epoch 86/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0240
# Epoch 87/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0220
# Epoch 88/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0229
# Epoch 89/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0236
# Epoch 90/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0228
# Epoch 91/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0229
# Epoch 92/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0214
# Epoch 93/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0228
# Epoch 94/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0215
# Epoch 95/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0220
# Epoch 96/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0203
# Epoch 97/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0232
# Epoch 98/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0219
# Epoch 99/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0212
# Epoch 100/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0195
# Epoch 101/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0215
# Epoch 102/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0212
# Epoch 103/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0200
# Epoch 104/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0221
# Epoch 105/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0188
# Epoch 106/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0222
# Epoch 107/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0187
# Epoch 108/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0203
# Epoch 109/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0201
# Epoch 110/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0193
# Epoch 111/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0187
# Epoch 112/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0187
# Epoch 113/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0209
# Epoch 114/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0208
# Epoch 115/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0176
# Epoch 116/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0196
# Epoch 117/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0181
# Epoch 118/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0181
# Epoch 119/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0198
# Epoch 120/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0170
# Epoch 121/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0209
# Epoch 122/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0196
# Epoch 123/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0166
# Epoch 124/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0184
# Epoch 125/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0190
# Epoch 126/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0198
# Epoch 127/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0180
# Epoch 128/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0160
# Epoch 129/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0192
# Epoch 130/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0171
# Epoch 131/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0160
# Epoch 132/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0192
# Epoch 133/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0155
# Epoch 134/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0217
# Epoch 135/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0156
# Epoch 136/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0152
# Epoch 137/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0210
# Epoch 138/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0157
# Epoch 139/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0165
# Epoch 140/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0161
# Epoch 141/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0183
# Epoch 142/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0187
# Epoch 143/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0155
# Epoch 144/200
# 1474/1474 [==============================] - 70s 47ms/step - loss: 0.0163
# Epoch 145/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0170
# Epoch 146/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0179
# Epoch 147/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0138
# Epoch 148/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0174
# Epoch 149/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0162
# Epoch 150/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0162
# Epoch 151/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0156
# Epoch 152/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0194
# Epoch 153/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0143
# Epoch 154/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0150
# Epoch 155/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0173
# Epoch 156/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0146
# Epoch 157/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0184
# Epoch 158/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0193
# Epoch 159/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0129
# Epoch 160/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0162
# Epoch 161/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0186
# Epoch 162/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0131
# Epoch 163/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0158
# Epoch 164/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0168
# Epoch 165/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0158
# Epoch 166/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0152
# Epoch 167/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0172
# Epoch 168/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0151
# Epoch 169/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0127
# Epoch 170/200
# 1474/1474 [==============================] - 70s 48ms/step - loss: 0.0174
# Epoch 171/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0172
# Epoch 172/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0131
# Epoch 173/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0140
# Epoch 174/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0179
# Epoch 175/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0139
# Epoch 176/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0145
# Epoch 177/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0159
# Epoch 178/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0129
# Epoch 179/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0144
# Epoch 180/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0146
# Epoch 181/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0140
# Epoch 182/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0141
# Epoch 183/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0159
# Epoch 184/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0144
# Epoch 185/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0169
# Epoch 186/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0118
# Epoch 187/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0169
# Epoch 188/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0145
# Epoch 189/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0128
# Epoch 190/200
# 1474/1474 [==============================] - 72s 49ms/step - loss: 0.0158
# Epoch 191/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0136
# Epoch 192/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0134
# Epoch 193/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0166
# Epoch 194/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0130
# Epoch 195/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0120
# Epoch 196/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0153
# Epoch 197/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0143
# Epoch 198/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0132
# Epoch 199/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0130
# Epoch 200/200
# 1474/1474 [==============================] - 71s 48ms/step - loss: 0.0165

# %%
 trainPredict_x = regressor_x.predict(x1_train)
trainPredict_v = regressor_v.predict(x1_train)

trainPredict_x = trainPredict_x.reshape(trainPredict_x.shape[0],trainPredict_x.shape[1])
trainPredict_v = trainPredict_v.reshape(trainPredict_v.shape[0],trainPredict_v.shape[1])

y1_train_cnt =  scaler_y_1.inverse_transform(y1_train.reshape(-1, n_out))
y2_train_cnt =  scaler_y_2.inverse_transform(y2_train.reshape(-1, n_out))

trainPredict_x_cnt = scaler_y_1.inverse_transform(trainPredict_x)
trainPredict_v_cnt = scaler_y_2.inverse_transform(trainPredict_v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-7832bfc2b09c> in <module>()
#       5 trainPredict_v = trainPredict_v.reshape(trainPredict_v.shape[0],trainPredict_v.shape[1])
#       6
# ----> 7 y1_train_cnt =  scaler_y_1.inverse_transform(y1_train.reshape(-1, n_out))
#       8 y2_train_cnt =  scaler_y_2.inverse_transform(y2_train.reshape(-1, n_out))
#       9
#
# NameError: name 'scaler_y_1' is not defined

# %%
np.shape(y1_test.reshape(-1, n_out))

# %%
scaler_y_1_ls[0].inverse_transform(y1_test.reshape(-1, n_out)[0].reshape(-1, 1))

# %%
test_len = len(scaler_y_1_ls[np.shape(trainPredict_x)[0]:])

y1_test_cnt = np.empty([len(scaler_y_1_ls[np.shape(trainPredict_x)[0]:]), n_out])
y2_test_cnt = np.empty([len(scaler_y_2_ls[np.shape(trainPredict_x)[0]:]), n_out])

testPredict_x_cnt = np.empty([len(scaler_y_1_ls[np.shape(trainPredict_x)[0]:]), n_out])
testPredict_v_cnt = np.empty([len(scaler_y_2_ls[np.shape(trainPredict_x)[0]:]), n_out])

testPredict_x = regressor_x.predict(x1_test)
testPredict_v = regressor_v.predict(x1_test)
testPredict_x = testPredict_x.reshape(testPredict_x.shape[0],testPredict_x.shape[1])
testPredict_v = testPredict_v.reshape(testPredict_v.shape[0],testPredict_v.shape[1])

for i in range(len(scaler_y_1_ls[np.shape(trainPredict_x)[0]:])):
  y1_test_cnt[i] = scaler_y_1_ls[i + test_len].inverse_transform(y1_test.reshape(-1, n_out)[i].reshape(-1, 1)).reshape(1,-1)
  y2_test_cnt[i] = scaler_y_2_ls[i + test_len].inverse_transform(y2_test.reshape(-1, n_out)[i].reshape(-1, 1)).reshape(1,-1)
  testPredict_x_cnt[i] = scaler_y_1_ls[i + test_len].inverse_transform(testPredict_x[i].reshape(-1, 1)).reshape(1,-1)
  testPredict_v_cnt[i] = scaler_y_2_ls[i + test_len].inverse_transform(testPredict_v[i].reshape(-1, 1)).reshape(1,-1)

# %%
a.reshape(1,-1)

# %%
len(y1_test_cnt)

# %%
testPredict_x = regressor_x.predict(x1_test)
testPredict_v = regressor_v.predict(x1_test)

testPredict_x = testPredict_x.reshape(testPredict_x.shape[0],testPredict_x.shape[1])
testPredict_v = testPredict_v.reshape(testPredict_v.shape[0],testPredict_v.shape[1])

y1_test_cnt =  scaler_y_1.inverse_transform(y1_test.reshape(-1, n_out))
y2_test_cnt =  scaler_y_2.inverse_transform(y2_test.reshape(-1, n_out))

testPredict_x_cnt = scaler_y_1.inverse_transform(testPredict_x)
testPredict_v_cnt = scaler_y_2.inverse_transform(testPredict_v)

# %% [markdown]
# # **Train**

# %%
start = 0
end = 2000
duration = end - start + 1
plt.figure(figsize=(20, 12))  
plt.plot(range(1,duration),y1_train_cnt[start:end,0]/3.28084,'green',label='GT',linewidth = 3, alpha=0.6)
plt.plot(range(n_out+1,duration + n_out),trainPredict_x_cnt[start:end,n_out-1]/3.28084,'blue',label='Prediction at 5s',linewidth = 3, alpha=0.3)
# m = 1
# for i in range(start,end,2):
#   traj = np.insert(trainPredict_x_cnt[i][:n_out], 0, y1_train_cnt[start:end,0][m-1], axis=0)
#   plt.plot(range(m,m+n_out+1),traj/3.28084,'gray', alpha=0.6)
#   m = m + 2
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Lateral Position Prediction w/ Train dataset (5s Forecast)', fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('Relative Lateral Position (m)', fontsize='14')
plt.show

# %%
plt.figure(figsize=(20, 12))  
plt.plot(range(1,duration),y2_train_cnt[start:end,0]*1.09728,'green',label='GT',linewidth = 3, alpha=0.6)
plt.plot(range(1+n_out,duration+n_out),trainPredict_v_cnt[start:end,n_out-1]*1.09728,'blue',label='Prediction at 5s',linewidth = 3, alpha=0.3)
# m = 1
# for i in range(start,end,2):
#   traj = np.insert(trainPredict_v_cnt[i][:], 0, y2_train_cnt[start:end,0][m-1], axis=0)
#   plt.plot(range(m,m+n_out+1),traj*1.09728,'gray', alpha=0.6)
#   m = m + 2
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Longitudinal Velocity Prediction w/ Train dataset (5s Forecast)', fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('Longitudinal Velocity (km/h)', fontsize='14')
plt.show

# %% [markdown]
# # **Test**

# %%
start = 430
end = 600


# start = 15994
# end = 16127
duration = end - start + 1
plt.figure(figsize=(20, 12))  
plt.plot(range(1,duration),y1_test_cnt[start:end,0]/3.28084,'green',label='GT',linewidth = 3, alpha=0.6)
plt.plot(range(1+n_out,duration+n_out),testPredict_x_cnt[start:end,n_out-1]/3.28084,'blue',label='Prediction at ' +str(n_out)+'s',linewidth = 3, alpha=0.3)
m = 1
for i in range(start,end,2):
  traj = np.insert(testPredict_x_cnt[i][:], 0, y1_test_cnt[start:end,0][m-1], axis=0)
  plt.plot(range(m,m+n_out+1),traj/3.28084,'gray', alpha=0.6)
  m = m + 2
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Lateral Position Prediction w/ Test dataset ("+ str(n_out) +"s Forecast)", fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('Relative Lateral Position (m)', fontsize='14')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(20, 12))  
plt.plot(range(1,duration),y2_test_cnt[start:end,0]*1.09728,'green',label='GT',linewidth = 3, alpha=0.6)
plt.plot(range(1+n_out,duration+n_out),testPredict_v_cnt[start:end,n_out-1]*1.09728,'blue',label='Prediction at ' +str(n_out)+'s',linewidth = 3, alpha=0.3)
m = 1
for i in range(start,end,2):
  traj = np.insert(testPredict_v_cnt[i][:], 0, y2_test_cnt[start:end,0][m-1], axis=0)
  plt.plot(range(m,m+n_out+1),traj*1.09728,'gray', alpha=0.6)
  m = m + 2
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Longitudinal Speed Prediction w/ Test dataset ("+ str(n_out) +"s Forecast)", fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('Longitudinal Speed (km/h)', fontsize='14')
plt.show

# %%
regressor_x.save('model_x_6_10.h5')
regressor_v.save('model_v_6_10.h5')

# %%
regressor_x.save('model_x_10_8.h5')
regressor_v.save('model_v_10_8.h5')

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms_x = sqrt(mean_squared_error(y1_test_cnt[:,n_out-1]/3.28084, testPredict_x_cnt[:,n_out-1]/3.28084))
rms_v = sqrt(mean_squared_error(y2_test_cnt[:,n_out-1]*1.09728, testPredict_v_cnt[:,n_out-1]*1.09728))
print("Lateral position prediction RMS at " + str(n_out) + "-th second is "+ str(np.around(rms_x, 2)) + " m")
print("Longitudinal speed prediction RMS at " + str(n_out) + "-th second is "+ str(np.around(rms_v/3.6, 2)) + " m/s")

# %%
rms_x_ls, rms_v_ls = [],[]
for i in range(0, n_out):
  rms_x_ls.append(sqrt(mean_squared_error(y1_test_cnt[:,i]/3.28084, testPredict_x_cnt[:,i]/3.28084)))
  rms_v_ls.append(sqrt(mean_squared_error(y2_test_cnt[:,i]*1.09728, testPredict_v_cnt[:,i]*1.09728)))

# %%
plt.figure(figsize=(10, 5))  
plt.plot(range(1,n_out+1),rms_x_ls,'green',label='RMS Lateral Pos',linewidth = 3, alpha=0.6)
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('RMS Trend for '+str(n_out)+" sec prediction based on past "+str(n_in)+" sec", fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('RMS (m)', fontsize='14')
plt.show

# %%
plt.figure(figsize=(10, 5))  
plt.plot(range(1,n_out+1),rms_v_ls,'blue',label='RMS Longitudinal Spd',linewidth = 3, alpha=0.6)
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('RMS Trend for '+str(n_out)+" sec prediction based on past "+str(n_in)+" sec", fontsize='16')
plt.xlabel('Time (s)', fontsize='14')
plt.ylabel('RMS (km/h)', fontsize='14')
plt.show

# %%
result_x_paper = [0.46, 0.52, 0.61, 0.68]
result_x_10 = [0.22, 0.34, 0.46, 0.59]
result_x_6 = [0.23, 0.35, 0.46, 0.57]
result_x_4 = [0.24, 0.36, 0.46, 0.57]
t = [4, 6, 8, 10]
plt.figure(figsize=(12, 6))  
plt.plot(t,result_x_paper,'grey',label='ByPass LSTM (Ref.): Input = 10s',linewidth = 3, alpha=0.9)
plt.plot(t,result_x_10,'blue',label='AE-BiLSTM: Input = 10s',linewidth = 3, alpha=0.5)
plt.plot(t,result_x_6,'magenta',label='AE-BiLSTM: Input = 6s',linewidth = 3, alpha=0.5)
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Lane-changing (lateral position) prediction w/ different input sizes', fontsize='16')
plt.xlabel('Prediction at i-th second', fontsize='14')
plt.ylabel('RMS (m)', fontsize='14')
plt.show

# %%
result_v_paper = [1.26, 1.76, 2.30, 2.78]
result_v_10 = [0.81, 1.46, 2.12, 2.74]
result_v_6 = [0.74, 1.39, 2.11, 2.71]
t = [4, 6, 8, 10]
plt.figure(figsize=(12, 6))  
plt.plot(t,result_v_paper,'grey',label='ByPass LSTM (Ref.): Input = 10s',linewidth = 3, alpha=0.9)
plt.plot(t,result_v_10,'blue',label='AE-BiLSTM: Input = 10s',linewidth = 3, alpha=0.5)
plt.plot(t,result_v_6,'magenta',label='AE-BiLSTM: Input = 6s',linewidth = 3, alpha=0.5)
plt.legend(loc='best', fontsize='12')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Longitudinal speed prediction w/ different input sizes', fontsize='16')
plt.xlabel('Prediction at i-th second', fontsize='14')
plt.ylabel('RMS (m/s)', fontsize='14')
plt.show
